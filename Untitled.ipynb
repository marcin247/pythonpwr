# %%
print ("podaj wartosc:")
x=int(input())
print("wartość 2 jest", 2*x)
# Out:
# podaj wartosc:
#  2
# wartość 2 jest 4

# %%
y = [0, 1, 2, 3, 4]
print(y)
print(len(y))
# Out:
# [0, 1, 2, 3, 4]
# 5

# %%
name = "            Matthew Magda"
greeting = "Hello"
print(greeting, name.upper())
# Out:
# Hello             MATTHEW MAGDA

# %%
name = "            Matthew Magda"
greeting = "Hello"
print(greeting, name.strip())
# Out:
# Hello Matthew Magda

# %%
plot([1,2,3,2,3,4,3,4,5])
show()

# %%
print("Insert value")
p=int(input())
y=p+p**p
show(y)
# Out:
# Insert value
#  2

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-3,3,100)
y=(x-1)**2
plt.plot(x,y,color="darkorange",lw=3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 100, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()
